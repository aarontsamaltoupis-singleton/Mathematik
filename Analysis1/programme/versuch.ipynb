# %%
def acht(n):
    aacht = 0
    for x in range(0,n):
        aacht += (10**x)*8
        
    return aacht
for n in range(1,50):
    print(10**n/acht(n))
# Out:
# 1.25
# 1.1363636363636365
# 1.1261261261261262
# 1.125112511251125
# 1.1250112501125011
# 1.125001125001125
# 1.1250001125000113
# 1.12500001125
# 1.125000001125
# 1.1250000001125
# 1.12500000001125
# 1.125000000001125
# 1.1250000000001126
# 1.1250000000000113
# 1.125000000000001
# 1.1250000000000002
# 1.125
# 1.125
# 1.125
# 1.125
# 1.125
# 1.125
# 1.125
# 1.125
# 1.125
# 1.125
# 1.125
# 1.125
# 1.125
# 1.125
# 1.125
# 1.125
# 1.125
# 1.125
# 1.125
# 1.125
# 1.125
# 1.125
# 1.125
# 1.125
# 1.125
# 1.125
# 1.125
# 1.125
# 1.125
# 1.125
# 1.125
# 1.125
# 1.125

# %%
ohneneun = 0
mitneun = 0
#anzahl ist die anzahl an zahlen in dem zahlenraum, die keine 9 enthalten
n = 100000
for n in range(n,2*n):
    if str(9) not in str(n):
        ohneneun+=1
    else:
        mitneun+=1

print(n/ohneneun)
print(mitneun/ohneneun)
print(mitneun, ohneneun)
# Out:
# 3.387000626598249
# 0.6935087808430287
# 40951 59049

# %%
import matplotlib.pyplot as plt


def nohneneun(n):
    ohneneunen = []
    test = 1
    while len(ohneneunen) < n:
        if str(9) not in str(test):
            ohneneunen.append(test)
        test +=1

    rueckgabe = 0
    for x in ohneneunen:
        rueckgabe += 1/x
        
    return rueckgabe 

def nmitallem(n):
    rueckgabe = 0
    for x in range(1,n+1):
        rueckgabe += 1/x
    return rueckgabe

n = 1000000
y = []
y2 = []
for n in range(1,n+1):
    y.append(nohneneun(n))

for n in range(1,n+1):
    y2.append(nmitallem(n))


x = range(1,n+1)


plt.plot(x,y2)
plt.plot(x, y)
plt.show()
#def nquadrat(n):
#    rueckgabe = 0
#    for x in range(1,n+1):
#        rueckgabe += 1/(x**2)
#
#    return rueckgabe





print(nquadrat(n),nohneneun(n))
