# %%
# folge aller zahlen ohne 9
def c(n):
    c = []
    f = []
    x = 1
    while len(c)<n:
        if str(9) not in str(x):
            c.append(x)
                
            
        x+=1
    return c

# anzahl aller zahlen ohne 9 zwischen 1 und n
def f(n):
    f = []
    for x in range(1,n+1):
        if str(9) not in str(x):
            f.append(x)
    return len(f)
    
# anzahl aller zahlen mit 9 zwischen 1 und n
def e(m,n):
    e = []
    for x in range(m,n+1):
        if str(9) in str(x):
            e.append(x)

    return (len(e))
    

# folge aller zahlen
def id(n):
    return list(range(1,n+1))

# %%
print(e(10))
# Out:
# 1

# %%
i = 3
m = c(10**i)
for n in range(1,10**i+1):
    print(n, m[n-1])


print(1000+e(1000))

# %%
i = 6
n = 10**i

# %%
print(c(10**i)[-1])
print(8*9**(1.04*i-1))
# Out:
# 14641
# 8288.888865735176

# %%
for i in range(1,10):
    n =  10**i
    print(c(n)[-1]/n)
# Out:
# 1.1
# 1.21
# 1.331
# 1.4641
# 1.62151
# 1.783661
# 2.0731371
# 2.28145181

# %%
for i in range(1,10):
    print(c(10**i)[-1])
    print(10**i+e(1,10**i)+(e(10**i,10**ii+e(10**i))))
