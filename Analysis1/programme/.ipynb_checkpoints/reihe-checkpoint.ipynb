# %%
# folge aller zahlen ohne 9
def c(n):
    c = []
    f = []
    x = 1
    while len(c)<n:
        if str(9) not in str(x):
            c.append(x)
                
            
        x+=1
    return c

# anzahl aller zahlen ohne 9 zwischen 1 und n
def f(n):
    f = []
    for x in range(1,n+1):
        if str(9) not in str(x):
            f.append(x)
    return len(f)
    
# anzahl aller zahlen mit 9 zwischen 1 und n
def e(m,n):
    e = []
    for x in range(m,n+1):
        if str(9) in str(x):
            e.append(x)

    return (len(e))
    

# folge aller zahlen
def id(n):
    return list(range(1,n+1))

# %%
i = 6
n = 10**i

# %%
print(c(9**(i))[-1])
print(9**i)
print(f(10**i))
# Out:
# 1000000
# 531441
# 531441

# %%
for x in range(1,50):
    print(10**(0.4*x)-x**2)
# Out:
# 1.5118864315095801
# 2.3095734448019334
# 6.848931924611142
# 23.810717055349734
# 75.0
# 215.18864315095823
# 581.9573444801937
# 1520.893192461114
# 3900.0717055349733
# 9900.0
# 24997.864315095823
# 62951.73444801943
# 158320.3192461114
# 397911.17055349774
# 999775.0
# 2511630.4315095823
# 6309284.444801942
# 15848607.924611142
# 39810356.055349775
# 99999600.0
# 251188202.1509582
# 630956860.4801943
# 1584892663.4611173
# 3981071129.5349855
# 9999999375.0
# 25118863639.09582
# 63095733719.019424
# 158489318462.11172
# 398107169712.49854
# 999999999100.0
# 2511886430548.582
# 6309573443777.942
# 15848931923522.174
# 39810717054193.85
# 99999999998775.0
# 251188643149662.22
# 630957344478825.2
# 1584893192459673.2
# 3981071705533464.5
# 9999999999998400.0
# 2.5118864315094244e+16
# 6.309573444801766e+16
# 1.5848931924610925e+17
# 3.9810717055349664e+17
# 9.99999999999998e+17
# 2.5118864315095905e+18
# 6.30957344480194e+18
# 1.5848931924611236e+19
# 3.981071705534986e+19
